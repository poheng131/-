# %% [markdown]
# ### 匯入套件

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 匯入檔案

# %%
current_dir = os.getcwd()
input_path=os.path.join(current_dir,r"../../data/104_cleaned_0718.csv")

df=pd.read_csv(input_path)
print(df.head())
# Out:
#        上架日期  申請人數        產業              公司名稱  \
# 0  20250709     5  雜誌／期刊出版業  今周刊_今周文化事業股份有限公司
# 1  20250715     4    人力仲介代徵      藝珂人事顧問股份有限公司
# 2  20250717     6    半導體製造業      錼創顯示科技股份有限公司
# 3  20250604     5  大專校院教育事業          國立臺北科技大學
# 4  20250625    11   工商顧問服務業          世銳顧問有限公司
#
#                                          description   縣市  \
# 0  1.【必備】Google Analytics技能。 \n2.【必備】熟稔Excel(函數、樞...  台北市
# 1  數據洞察與分析\n分析商品分類、顧客行為、流量來源、轉換率等電商關鍵指標，找出成長機會與潛在...  台北市
# 2  1. 分析生產數據與大數據建模，協助建立品質監測與異常偵測模型，提供優化建議。\n2. 參與...  苗栗縣
# 3  作，成果應用於企業與政府智慧城市專案。加入我們，您將成為城市科學的先鋒，與世界領先的團隊共創...  台北市
# 4  題，為客戶提供具有價值的服務並且協助推動客戶的財務成長。服務內容包括：\n‧\t打造具有吸引...  台北市
#
#                         職稱      工作編號  工作型態         經度  ...  是否遠距   薪資上限  \
# 0         數據分析師【今周刊─數位內容部】  14090732     2  25.051911  ...     0      0
# 1              [電商] 數據分析主管  14739101     0  25.040652  ...     0      0
# 2                  數據分析工程師  14535114     0  24.711336  ...     0      0
# 3  MITxTaipei Tech 都市數據分析師  13817654     0  25.041802  ...     0      0
# 4                  商業數據分析師  14079349     0  25.053372  ...     0  60000
#
#     薪資下限  工作時段                                職務分類代碼  是否積極徵才  \
# 0      0   NaN              [2007001018, 2007001022]       0
# 1      0   NaN  [2004001010, 2007001018, 2007001021]       0
# 2      0   NaN                          [2007001018]       0
# 3      0   NaN  [2007001022, 2007001004, 2008001009]       0
# 4  50000   NaN  [2007001021, 2007001018, 2004003006]       1
#
#                                                 條件要求  \
# 0  {'acceptRole': {'role': [{'code': 64, 'descrip...
# 1  {'acceptRole': {'role': [], 'disRole': {'needH...
# 2  {'acceptRole': {'role': [], 'disRole': {'needH...
# 3  {'acceptRole': {'role': [{'code': 2, 'descript...
# 4  {'acceptRole': {'role': [{'code': 2, 'descript...
#
#                                                 福利制度  員工人數 搜尋關鍵字
# 0  {'tag': [], 'welfare': '★薪資保障\n1.年終獎金 \n2.三節禮金...  217人  數據分析
# 1         {'tag': [], 'welfare': '', 'legalTag': []}  暫不提供  數據分析
# 2  {'tag': ['年終獎金', '三節獎金/禮品', '專業證照獎金', '咖啡吧', '...  500人  數據分析
# 3         {'tag': [], 'welfare': '', 'legalTag': []}  暫不提供  數據分析
# 4  {'tag': ['年終獎金', '零食櫃', '咖啡吧', '社團補助', '退職金提撥'...   20人  數據分析
#
# [5 rows x 23 columns]

# %% [markdown]
# # 了解資料

# %% [markdown]
# ### 查看基本信息(資料類型、缺失值數量、欄位)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 866 entries, 0 to 865
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   上架日期         866 non-null    int64
#  1   申請人數         866 non-null    int64
#  2   產業           866 non-null    object
#  3   公司名稱         866 non-null    object
#  4   description  866 non-null    object
#  5   縣市           866 non-null    object
#  6   職稱           866 non-null    object
#  7   工作編號         866 non-null    int64
#  8   工作型態         866 non-null    int64
#  9   經度           866 non-null    float64
#  10  緯度           866 non-null    float64
#  11  major        866 non-null    object
#  12  學歷要求         866 non-null    object
#  13  是否遠距         866 non-null    int64
#  14  薪資上限         866 non-null    int64
#  15  薪資下限         866 non-null    int64
#  16  工作時段         258 non-null    object
#  17  職務分類代碼       866 non-null    object
#  18  是否積極徵才       866 non-null    int64
#  19  條件要求         866 non-null    object
#  20  福利制度         866 non-null    object
#  21  員工人數         866 non-null    object
#  22  搜尋關鍵字        866 non-null    object
# dtypes: float64(2), int64(8), object(13)
# memory usage: 155.7+ KB

# %%
#了解各欄缺失值數量
df.isnull().sum()
# Out:
# 上架日期             0
# 申請人數             0
# 產業               0
# 公司名稱             0
# description      0
# 縣市               0
# 職稱               0
# 工作編號             0
# 工作型態             0
# 經度               0
# 緯度               0
# major            0
# 學歷要求             0
# 是否遠距             0
# 薪資上限             0
# 薪資下限             0
# 工作時段           608
# 職務分類代碼           0
# 是否積極徵才           0
# 條件要求             0
# 福利制度             0
# 員工人數             0
# 搜尋關鍵字            0
# dtype: int64

# %% [markdown]
# ### 進一步移除不需要的欄位資料

# %%
df.drop(columns=['工作時段','工作型態','職務分類代碼','薪資上限','福利制度','上架日期','申請人數','搜尋關鍵字','是否積極徵才','description'],inplace=True)

# %%
df.shape
# Out:
# (866, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 866 entries, 0 to 865
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   產業      866 non-null    object
#  1   公司名稱    866 non-null    object
#  2   縣市      866 non-null    object
#  3   職稱      866 non-null    object
#  4   工作編號    866 non-null    int64
#  5   經度      866 non-null    float64
#  6   緯度      866 non-null    float64
#  7   major   866 non-null    object
#  8   學歷要求    866 non-null    object
#  9   是否遠距    866 non-null    int64
#  10  薪資下限    866 non-null    int64
#  11  條件要求    866 non-null    object
#  12  員工人數    866 non-null    object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 88.1+ KB

# %%
df.head()
# Out:
#          產業              公司名稱   縣市                       職稱      工作編號  \
# 0  雜誌／期刊出版業  今周刊_今周文化事業股份有限公司  台北市         數據分析師【今周刊─數位內容部】  14090732
# 1    人力仲介代徵      藝珂人事顧問股份有限公司  台北市              [電商] 數據分析主管  14739101
# 2    半導體製造業      錼創顯示科技股份有限公司  苗栗縣                  數據分析工程師  14535114
# 3  大專校院教育事業          國立臺北科技大學  台北市  MITxTaipei Tech 都市數據分析師  13817654
# 4   工商顧問服務業          世銳顧問有限公司  台北市                  商業數據分析師  14079349
#
#           經度          緯度                                 major  \
# 0  25.051911  121.526154                                    []
# 1  25.040652  121.565297                                    []
# 2  24.711336  120.913172  ['數理統計相關', '工業工程相關', '其他數學及電算機科學相關']
# 3  25.041802  121.534887                                    []
# 4  25.053372  121.522852        ['一般商業學類', '醫藥工程相關', '數理統計相關']
#
#               學歷要求  是否遠距   薪資下限  \
# 0           [4, 5]     0      0
# 1              [5]     0      0
# 2              [5]     0      0
# 3        [4, 5, 6]     0      0
# 4  [2, 3, 4, 5, 6]     0  50000
#
#                                                 條件要求  員工人數
# 0  {'acceptRole': {'role': [{'code': 64, 'descrip...  217人
# 1  {'acceptRole': {'role': [], 'disRole': {'needH...  暫不提供
# 2  {'acceptRole': {'role': [], 'disRole': {'needH...  500人
# 3  {'acceptRole': {'role': [{'code': 2, 'descript...  暫不提供
# 4  {'acceptRole': {'role': [{'code': 2, 'descript...   20人

# %% [markdown]
# # 薪資欄位處理
# <p>薪資欄位: </p>
# <p>1.「薪資下限」、「薪資上限」兩欄</p>
# <p>2.【月薪】【時薪】【年薪】混雜</p>
# <p>3.需多為0的資料</p>

# %%
df['薪資是否為面議']= np.where(df['薪資下限']==0,1,0) #增加'薪資是否為面議'欄位
df['薪資下限']=df['薪資下限'].replace(0,40000)    #將面議的改成法規規定最低40000
df=df[df['薪資下限']>=1000]     #將時薪(非正職、學生實習)的資料去除

#自動判斷月薪超過300000為年薪，並除以12，轉為月薪
df['薪資下限'] = df['薪資下限'].astype(float)   #原本欄位是(int)類型，除12後會變float，會相衝，故先轉成float。
df.loc[df['薪資下限'] > 300000, '薪資下限']/= 12
df['薪資下限'] = df['薪資下限'].round(0).astype(int)

# %% [markdown]
# ## 增加欄位「是否要求特定major」，用來探索性分析。(*非本次分析重點，可略過)

# %%
df['major']
# Out:
# 0                                        []
# 1                                        []
# 2      ['數理統計相關', '工業工程相關', '其他數學及電算機科學相關']
# 3                                        []
# 4            ['一般商業學類', '醫藥工程相關', '數理統計相關']
#                        ...
# 861          ['統計學相關', '資訊管理相關', '大眾傳播學相關']
# 862                                      []
# 863                                      []
# 864           ['統計學相關', '資訊工程相關', '資訊管理相關']
# 865             ['商業及管理學科類', '數學及電算機科學學科類']
# Name: major, Length: 848, dtype: object

# %%
import ast # 導入 ast 模組
df["是否要求特定major"] = df['major'].apply(lambda x: 1 if len(ast.literal_eval(x)) > 0 else 0) #增加一欄，[是否要求特定major]的欄位。

# %%
df['是否要求特定major'].tail(20)
# Out:
# 846    0
# 847    1
# 848    0
# 849    0
# 850    1
# 851    0
# 852    1
# 853    0
# 854    0
# 855    0
# 856    1
# 857    1
# 858    0
# 859    0
# 860    1
# 861    1
# 862    0
# 863    0
# 864    1
# 865    1
# Name: 是否要求特定major, dtype: int64

# %% [markdown]
# ## 將 「是否遠距」欄位原本的編碼，還原為對應的字串(*非本次分析重點，可略過)

# %%
df['是否遠距'].value_counts()
# Out:
# 是否遠距
# 0    768
# 2     70
# 1     10
# Name: count, dtype: int64

# %%
df['是否遠距'] = df['是否遠距'].astype(int)

# %%
remote_work={0:"無遠距",1:"完全遠距",2:"混和"}
df['是否遠距']=df['是否遠距'].map(remote_work)

# %%
df.head()
# Out:
#          產業              公司名稱   縣市                       職稱      工作編號  \
# 0  雜誌／期刊出版業  今周刊_今周文化事業股份有限公司  台北市         數據分析師【今周刊─數位內容部】  14090732
# 1    人力仲介代徵      藝珂人事顧問股份有限公司  台北市              [電商] 數據分析主管  14739101
# 2    半導體製造業      錼創顯示科技股份有限公司  苗栗縣                  數據分析工程師  14535114
# 3  大專校院教育事業          國立臺北科技大學  台北市  MITxTaipei Tech 都市數據分析師  13817654
# 4   工商顧問服務業          世銳顧問有限公司  台北市                  商業數據分析師  14079349
#
#           經度          緯度                                 major  \
# 0  25.051911  121.526154                                    []
# 1  25.040652  121.565297                                    []
# 2  24.711336  120.913172  ['數理統計相關', '工業工程相關', '其他數學及電算機科學相關']
# 3  25.041802  121.534887                                    []
# 4  25.053372  121.522852        ['一般商業學類', '醫藥工程相關', '數理統計相關']
#
#               學歷要求 是否遠距   薪資下限  \
# 0           [4, 5]  無遠距  40000
# 1              [5]  無遠距  40000
# 2              [5]  無遠距  40000
# 3        [4, 5, 6]  無遠距  40000
# 4  [2, 3, 4, 5, 6]  無遠距  50000
#
#                                                 條件要求  員工人數  薪資是否為面議  \
# 0  {'acceptRole': {'role': [{'code': 64, 'descrip...  217人        1
# 1  {'acceptRole': {'role': [], 'disRole': {'needH...  暫不提供        1
# 2  {'acceptRole': {'role': [], 'disRole': {'needH...  500人        1
# 3  {'acceptRole': {'role': [{'code': 2, 'descript...  暫不提供        1
# 4  {'acceptRole': {'role': [{'code': 2, 'descript...   20人        0
#
#    是否要求特定major
# 0            0
# 1            0
# 2            1
# 3            0
# 4            1

# %% [markdown]
# # 去除「工作編號」重複的資料，設定「工作編號」為index

# %%
df[df["工作編號"].duplicated()]
# Out:
#                 產業                 公司名稱   縣市  \
# 170        生化科技研發業           俊質生醫股份有限公司  台南市
# 190   電子通訊／電腦週邊零售業           全國電子股份有限公司  新北市
# 200         半導體製造業         錼創顯示科技股份有限公司  苗栗縣
# 203    其他專業／科學及技術業     工研院 _財團法人工業技術研究院  新竹縣
# 204  印刷電路板製造業(PCB)      台郡科技股份有限公司(總公司)  高雄市
# ..             ...                  ...  ...
# 854          金融控股業    國泰金控_國泰金融控股股份有限公司  台北市
# 856         半導體製造業  台灣積體電路製造股份有限公司(台積電)  新竹縣
# 858       多媒體傳播相關業       杰德創意影音管理股份有限公司  台北市
# 863        網際網路相關業             盛形通運有限公司  台北市
# 865       多媒體傳播相關業             凱擘股份有限公司  台北市
#
#                                                     職稱      工作編號         經度  \
# 170                                        數據分析工程師(南科)  14437293  23.097413
# 190                              總公司-IT部門/數據分析及報表開發工程師  14010560  25.068519
# 200                                            數據分析工程師  14535114  24.711336
# 203                            工研院機械所-電動車數據分析工程師(D400)  14491156  24.774192
# 204                                            數據分析工程師  12937778  22.593423
# ..                                                 ...       ...        ...
# 854  資料科學架構師 Data Architect -數據科技-(數數發中心, DDT)_I000...  14044950  25.024944
# 856  AI & Data Analysis Engineer (Dept: AQSD, Div: ...  14106415  24.742791
# 858                                              數據分析師  14540514  25.024347
# 863                                             數據分析專員  14604483  25.077849
# 865                             【幸福企業招募】內湖總部 - 數據分析管理師  13808424  25.079958
#
#              緯度                                 major       學歷要求 是否遠距   薪資下限  \
# 170  120.284034                ['電機電子工程相關', '資訊工程相關']        [4]  無遠距  38000
# 190  121.446064                                    []     [4, 5]  無遠距  40000
# 200  120.913172  ['數理統計相關', '工業工程相關', '其他數學及電算機科學相關']        [5]  無遠距  40000
# 203  121.047917                ['電機電子工程相關', '機械工程相關']     [5, 6]  無遠距  40000
# 204  120.428297            ['資訊工程相關', '其他數學及電算機科學相關']     [4, 5]  無遠距  40000
# ..          ...                                   ...        ...  ...    ...
# 854  121.543378                                    []  [4, 5, 6]  無遠距  40000
# 856  120.999103      ['機械工程相關', '電機電子工程相關', '資訊工程相關']     [5, 6]  無遠距  40000
# 858  121.548339                                    []  [4, 5, 6]  無遠距  48000
# 863  121.568373                                    []  [3, 4, 5]  無遠距  38000
# 865  121.571271           ['商業及管理學科類', '數學及電算機科學學科類']     [4, 5]  無遠距  31000
#
#                                                   條件要求   員工人數  薪資是否為面議  \
# 170  {'acceptRole': {'role': [{'code': 2, 'descript...    20人        0
# 190  {'acceptRole': {'role': [], 'disRole': {'needH...  1700人        1
# 200  {'acceptRole': {'role': [], 'disRole': {'needH...   500人        1
# 203  {'acceptRole': {'role': [{'code': 2, 'descript...  6000人        1
# 204  {'acceptRole': {'role': [], 'disRole': {'needH...  2000人        1
# ..                                                 ...    ...      ...
# 854  {'acceptRole': {'role': [], 'disRole': {'needH...   800人        1
# 856  {'acceptRole': {'role': [], 'disRole': {'needH...   暫不提供        1
# 858  {'acceptRole': {'role': [{'code': 32, 'descrip...   暫不提供        0
# 863  {'acceptRole': {'role': [{'code': 65536, 'desc...    18人        0
# 865  {'acceptRole': {'role': [], 'disRole': {'needH...  1150人        0
#
#      是否要求特定major
# 170            1
# 190            0
# 200            1
# 203            1
# 204            1
# ..           ...
# 854            0
# 856            1
# 858            0
# 863            0
# 865            1
#
# [258 rows x 15 columns]

# %%
df.drop_duplicates(subset="工作編號",keep="first",inplace=True)  #保留第一個

# %%
df.set_index("工作編號")
# Out:
#                 產業                公司名稱   縣市                       職稱  \
# 工作編號
# 14090732  雜誌／期刊出版業    今周刊_今周文化事業股份有限公司  台北市         數據分析師【今周刊─數位內容部】
# 14739101    人力仲介代徵        藝珂人事顧問股份有限公司  台北市              [電商] 數據分析主管
# 14535114    半導體製造業        錼創顯示科技股份有限公司  苗栗縣                  數據分析工程師
# 13817654  大專校院教育事業            國立臺北科技大學  台北市  MITxTaipei Tech 都市數據分析師
# 14079349   工商顧問服務業            世銳顧問有限公司  台北市                  商業數據分析師
# ...            ...                 ...  ...                      ...
# 14325959   電腦軟體服務業            不晚科技有限公司  台北市                     數據分析
# 14424533   廣告行銷公關業        華權數位整合行銷有限公司  台中市                    數據分析師
# 14724608   廣告行銷公關業          創浪行銷顧問有限公司  台北市                   數據分析經理
# 14620764   其他相關製造業  CONTIN 康定_奇來生技有限公司  高雄市                數位行銷數據分析師
# 14745746   育樂用品製造業        喬山健康科技股份有限公司  台北市        總部數位-數據分析師(台北中正區)
#
#                  經度          緯度                                 major  \
# 工作編號
# 14090732  25.051911  121.526154                                    []
# 14739101  25.040652  121.565297                                    []
# 14535114  24.711336  120.913172  ['數理統計相關', '工業工程相關', '其他數學及電算機科學相關']
# 13817654  25.041802  121.534887                                    []
# 14079349  25.053372  121.522852        ['一般商業學類', '醫藥工程相關', '數理統計相關']
# ...             ...         ...                                   ...
# 14325959  25.076077  121.575436                                    []
# 14424533  24.116516  120.615540         ['統計學相關', '數理統計相關', '應用數學相關']
# 14724608  25.034500  121.560053        ['統計學相關', '資訊管理相關', '大眾傳播學相關']
# 14620764  22.641587  120.385938                                    []
# 14745746  25.044908  121.515143         ['統計學相關', '資訊工程相關', '資訊管理相關']
#
#                      學歷要求 是否遠距   薪資下限  \
# 工作編號
# 14090732           [4, 5]  無遠距  40000
# 14739101              [5]  無遠距  40000
# 14535114              [5]  無遠距  40000
# 13817654        [4, 5, 6]  無遠距  40000
# 14079349  [2, 3, 4, 5, 6]  無遠距  50000
# ...                   ...  ...    ...
# 14325959           [3, 4]  無遠距  40000
# 14424533        [4, 5, 6]  無遠距  40000
# 14724608        [4, 5, 6]  無遠距  40000
# 14620764     [3, 4, 5, 6]  無遠距  40000
# 14745746     [3, 4, 5, 6]  無遠距  40000
#
#                                                        條件要求   員工人數  薪資是否為面議  \
# 工作編號
# 14090732  {'acceptRole': {'role': [{'code': 64, 'descrip...   217人        1
# 14739101  {'acceptRole': {'role': [], 'disRole': {'needH...   暫不提供        1
# 14535114  {'acceptRole': {'role': [], 'disRole': {'needH...   500人        1
# 13817654  {'acceptRole': {'role': [{'code': 2, 'descript...   暫不提供        1
# 14079349  {'acceptRole': {'role': [{'code': 2, 'descript...    20人        0
# ...                                                     ...    ...      ...
# 14325959  {'acceptRole': {'role': [], 'disRole': {'needH...    20人        1
# 14424533  {'acceptRole': {'role': [{'code': 2, 'descript...   暫不提供        0
# 14724608  {'acceptRole': {'role': [], 'disRole': {'needH...   暫不提供        1
# 14620764  {'acceptRole': {'role': [], 'disRole': {'needH...   暫不提供        0
# 14745746  {'acceptRole': {'role': [], 'disRole': {'needH...  8000人        1
#
#           是否要求特定major
# 工作編號
# 14090732            0
# 14739101            0
# 14535114            1
# 13817654            0
# 14079349            1
# ...               ...
# 14325959            0
# 14424533            1
# 14724608            1
# 14620764            0
# 14745746            1
#
# [590 rows x 14 columns]

# %% [markdown]
# # 縮減「產業」欄位成「八大產業」
# <p>因為104產業類型太多，且許多產業是非常相同的，不利於分析，故將類似的行業整合在一起</p>

# %%
#未縮減前，有81種產業別
df['產業'].nunique()
# Out:
# 81

# %%
#請參考同資料夾內 cleaning_industry.py 內容，其中有整合mapping對照表。
#這邊直接匯入預寫好的函數進行處理
from cleaning_industry import clean_industry_column
df=clean_industry_column(df)
df.drop(columns=["產業"],inplace=True)

# %%
df["八大產業"].value_counts()
# Out:
# 八大產業
# 資訊科技業       222
# 金融與保險業      110
# 服務與專業顧問業     93
# 製造業          90
# 批發與零售業       33
# 醫療與健康照護      20
# 其他           13
# 觀光與餐飲業        5
# 運輸與物流業        4
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                公司名稱   縣市                       職稱      工作編號         經度  \
# 0  今周刊_今周文化事業股份有限公司  台北市         數據分析師【今周刊─數位內容部】  14090732  25.051911
# 1      藝珂人事顧問股份有限公司  台北市              [電商] 數據分析主管  14739101  25.040652
# 2      錼創顯示科技股份有限公司  苗栗縣                  數據分析工程師  14535114  24.711336
# 3          國立臺北科技大學  台北市  MITxTaipei Tech 都市數據分析師  13817654  25.041802
# 4          世銳顧問有限公司  台北市                  商業數據分析師  14079349  25.053372
#
#            緯度                                 major             學歷要求 是否遠距  \
# 0  121.526154                                    []           [4, 5]  無遠距
# 1  121.565297                                    []              [5]  無遠距
# 2  120.913172  ['數理統計相關', '工業工程相關', '其他數學及電算機科學相關']              [5]  無遠距
# 3  121.534887                                    []        [4, 5, 6]  無遠距
# 4  121.522852        ['一般商業學類', '醫藥工程相關', '數理統計相關']  [2, 3, 4, 5, 6]  無遠距
#
#     薪資下限                                               條件要求  員工人數  薪資是否為面議  \
# 0  40000  {'acceptRole': {'role': [{'code': 64, 'descrip...  217人        1
# 1  40000  {'acceptRole': {'role': [], 'disRole': {'needH...  暫不提供        1
# 2  40000  {'acceptRole': {'role': [], 'disRole': {'needH...  500人        1
# 3  40000  {'acceptRole': {'role': [{'code': 2, 'descript...  暫不提供        1
# 4  50000  {'acceptRole': {'role': [{'code': 2, 'descript...   20人        0
#
#    是否要求特定major      八大產業
# 0            0  服務與專業顧問業
# 1            0  服務與專業顧問業
# 2            1       製造業
# 3            0  服務與專業顧問業
# 4            1  服務與專業顧問業

# %% [markdown]
# # 處理「學歷要求」欄位

# %%
#查看該欄位有哪些不同的值，以及有多少數量
df["學歷要求"].value_counts()
# Out:
# 學歷要求
# [4, 5, 6]             214
# [4, 5]                118
# [1, 2, 3, 4, 5, 6]     55
# [3, 4, 5, 6]           53
# [5, 6]                 48
# [3, 4, 5]              30
# [5]                    29
# [4]                    16
# [2, 3, 4, 5, 6]         9
# [3, 4]                  9
# [3]                     4
# [2, 3, 4, 5]            2
# [6]                     2
# [2, 3, 4]               1
# Name: count, dtype: int64

# %% [markdown]
# ### 產生對照字典，並依據最小的值去對照(學歷最低要求水準)(*非本次分析重點，可略過)

# %%
edu_map = {
            1: '不拘',
            2: '高中',
            3: '專科',
            4: '大學',
            5: '碩士',
            6: '博士',
        }
df['學歷要求']=df['學歷要求'].apply(lambda x:edu_map.get(min(ast.literal_eval(x))))

# %% [markdown]
# ### 透過公司人數，增加「公司規模」欄位，判斷是【大型公司】【中型公司】【小型公司】(*非本次分析重點，可略過)

# %%
df['員工人數'] = df['員工人數'].apply(lambda x: int(x.replace('人', '')) if isinstance(x, str) and x.endswith('人') else pd.NA) # 去'人'轉數字，並將'暫不提供'改為NA

# %%
#增加[公司規模]欄位，依員工人數劃分
def classify_company_size(num):       
    if pd.isnull(num):
        return '未知'
    elif num<50:
        return '小型'
    elif num < 200:
        return '中型'
    else:
        return '大型'
df['公司規模']=df['員工人數'].apply(classify_company_size)

# %% [markdown]
# # 處理「條件要求」欄位
# <p>該欄資料是一串dictionary，可以拆成許多欄位。</p>
# <p>本次處理重點為，拆出「專長工具」與「工作經驗」這兩個欄位。</p>
# <p>「專長工具」可以做為後續【核心技能要求】的分析。</p>

# %%
def parse_string(x):
    """
    將字串轉換為 Python 的資料結構（如字典、列表、數字等）。
    """
    if isinstance(x,str):
        try:
            return ast.literal_eval(x)
        except Exception as e:
            return {}
    return x
df['條件要求']=df['條件要求'].apply(parse_string)   
#提取工作經驗
df['工作經驗']=df['條件要求'].apply(lambda x:x.get('workExp') if isinstance(x,dict) else None)
#提取專長工具
def format_specialty(job_require_dict):

    if isinstance(job_require_dict,dict) and 'specialty' in job_require_dict:
        specialty_list=job_require_dict['specialty']
        if isinstance(specialty_list,list):
            descriptions=[s.get('description') for s in specialty_list if isinstance(s,dict) and s.get('description')]
            return ", ".join(descriptions)

    return None


df['專長工具']=df['條件要求'].apply(format_specialty)
df.drop(columns='條件要求',inplace=True)

# %%
df.tail()
# Out:
#                    公司名稱   縣市                 職稱      工作編號         經度  \
# 859            不晚科技有限公司  台北市               數據分析  14325959  25.076077
# 860        華權數位整合行銷有限公司  台中市              數據分析師  14424533  24.116516
# 861          創浪行銷顧問有限公司  台北市             數據分析經理  14724608  25.034500
# 862  CONTIN 康定_奇來生技有限公司  高雄市          數位行銷數據分析師  14620764  22.641587
# 864        喬山健康科技股份有限公司  台北市  總部數位-數據分析師(台北中正區)  14745746  25.044908
#
#              緯度                           major 學歷要求 是否遠距   薪資下限  員工人數  \
# 859  121.575436                              []   專科  無遠距  40000    20
# 860  120.615540   ['統計學相關', '數理統計相關', '應用數學相關']   大學  無遠距  40000  <NA>
# 861  121.560053  ['統計學相關', '資訊管理相關', '大眾傳播學相關']   大學  無遠距  40000  <NA>
# 862  120.385938                              []   專科  無遠距  40000  <NA>
# 864  121.515143   ['統計學相關', '資訊工程相關', '資訊管理相關']   專科  無遠距  40000  8000
#
#      薪資是否為面議  是否要求特定major      八大產業 公司規模  工作經驗  \
# 859        1            0     資訊科技業   小型  1年以上
# 860        0            1  服務與專業顧問業   未知  1年以上
# 861        1            1  服務與專業顧問業   未知  3年以上
# 862        0            0       製造業   未知  2年以上
# 864        1            1        其他   大型  7年以上
#
#                                                   專長工具
# 859                          Python, MySQL, PostgreSQL
# 860
# 861                            Excel, Google Analytics
# 862  Line, Instagram, Facebook, Google Analytics, G...
# 864   Tableau, Power BI​, Looker studio, Python, MySQL

# %% [markdown]
# ### 將清理完成的資料，匯出成CSV

# %%
#暫時匯出
#desktop_path = os.path.join(os.path.expanduser("~"), "Desktop", "暫時匯出查看.csv")
#df.to_csv(desktop_path, index=False, encoding='utf-8-sig')
